# %% [markdown]
# # Financial News Sentiment Analysis - EDA
#
# ## Overview
# In this notebook I explore the financial news dataset to understand
# its structure, content and patterns before doing sentiment analysis.
#
# The dataset contains over 1.4 million news headlines from 2009 to 2020.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("ready")
# Out:
# ready

# %%
df_news = pd.read_csv("../data/raw/raw_analyst_ratings.csv")
df_news.head()
# Out:
#    Unnamed: 0                                           headline  \
# 0           0            Stocks That Hit 52-Week Highs On Friday
# 1           1         Stocks That Hit 52-Week Highs On Wednesday
# 2           2                      71 Biggest Movers From Friday
# 3           3       46 Stocks Moving In Friday's Mid-Day Session
# 4           4  B of A Securities Maintains Neutral on Agilent...
#
#                                                  url          publisher  \
# 0  https://www.benzinga.com/news/20/06/16190091/s...  Benzinga Insights
# 1  https://www.benzinga.com/news/20/06/16170189/s...  Benzinga Insights
# 2  https://www.benzinga.com/news/20/05/16103463/7...         Lisa Levin
# 3  https://www.benzinga.com/news/20/05/16095921/4...         Lisa Levin
# 4  https://www.benzinga.com/news/20/05/16095304/b...         Vick Meyer
#
#                         date stock
# 0  2020-06-05 10:30:54-04:00     A
# 1  2020-06-03 10:45:20-04:00     A
# 2  2020-05-26 04:30:07-04:00     A
# 3  2020-05-22 12:45:06-04:00     A
# 4  2020-05-22 11:38:59-04:00     A

# %%
print("Shape of data:", df_news.shape)
print("Columns:", df_news.columns.tolist())
# Out:
# Shape of data: (1407328, 6)
# Columns: ['Unnamed: 0', 'headline', 'url', 'publisher', 'date', 'stock']

# %%
print("Missing values in each column:")
print(df_news.isnull().sum())
# Out:
# Missing values in each column:
# Unnamed: 0    0
# headline      0
# url           0
# publisher     0
# date          0
# stock         0
# dtype: int64

# %%
print("Number of unique stocks:", df_news['stock'].nunique())
print("Number of unique publishers:", df_news['publisher'].nunique())
print("\nTop 10 publishers:")
print(df_news['publisher'].value_counts().head(10))
# Out:
# Number of unique stocks: 6204
# Number of unique publishers: 1034
#
# Top 10 publishers:
# publisher
# Paul Quintaro        228373
# Lisa Levin           186979
# Benzinga Newsdesk    150484
# Charles Gross         96732
# Monica Gerson         82380
# Eddie Staley          57254
# Hal Lindon            49047
# ETF Professor         28489
# Juan Lopez            28438
# Benzinga Staff        28114
# Name: count, dtype: int64

# %%
# Add a new column that counts how many words are in each headline
df_news['headline_length'] = df_news['headline'].apply(len)

print("Headline length statistics:")
print(df_news['headline_length'].describe())
# Out:
# Headline length statistics:
# count    1.407328e+06
# mean     7.312051e+01
# std      4.073531e+01
# min      3.000000e+00
# 25%      4.700000e+01
# 50%      6.400000e+01
# 75%      8.700000e+01
# max      5.120000e+02
# Name: headline_length, dtype: float64

# %% [markdown]
# ## Publisher Analysis
# This shows the top 10 publishers by number of articles written.
# Paul Quintaro is the most active with over 228,000 articles.

# %%
plt.figure(figsize=(12, 6))
df_news['publisher'].value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Publishers by Number of Articles')
plt.xlabel('Publisher')
plt.ylabel('Number of Articles')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Headline Length Analysis
# Most headlines are between 47 and 87 characters long.
# The average headline length is 73 characters.

# %%
plt.figure(figsize=(12, 6))
df_news['headline_length'].hist(bins=50, color='steelblue', edgecolor='black')
plt.title('Distribution of Headline Lengths')
plt.xlabel('Headline Length (characters)')
plt.ylabel('Number of Headlines')
plt.tight_layout()
plt.show()

# %%
# Convert date column to proper date format
df_news['date'] = pd.to_datetime(df_news['date'], format='mixed', utc=True)

# Extract just the date (without time)
df_news['date_only'] = df_news['date'].dt.date

print("Date range of news:")
print("Earliest:", df_news['date'].min())
print("Latest:", df_news['date'].max())
# Out:
# Date range of news:
# Earliest: 2009-02-14 00:00:00+00:00
# Latest: 2020-06-11 21:12:35+00:00

# %% [markdown]
# ## News Volume Over Time
# This shows how many articles were published each year.
# We can see which years had the most financial news activity.

# %%
# Count articles per year
df_news['year'] = df_news['date'].dt.year

plt.figure(figsize=(12, 6))
df_news['year'].value_counts().sort_index().plot(kind='bar', color='steelblue')
plt.title('Number of News Articles Per Year')
plt.xlabel('Year')
plt.ylabel('Number of Articles')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
print("=== NEWS DATASET SUMMARY ===")
print(f"Total headlines: {df_news.shape[0]:,}")
print(f"Total columns: {df_news.shape[1]}")
print(f"Unique stocks: {df_news['stock'].nunique():,}")
print(f"Unique publishers: {df_news['publisher'].nunique():,}")
print(f"Date range: {df_news['date'].min()} to {df_news['date'].max()}")
print(f"Average headline length: {df_news['headline_length'].mean():.0f} characters")
# Out:
# === NEWS DATASET SUMMARY ===
# Total headlines: 1,407,328
# Total columns: 9
# Unique stocks: 6,204
# Unique publishers: 1,034
# Date range: 2009-02-14 00:00:00+00:00 to 2020-06-11 21:12:35+00:00
# Average headline length: 73 characters

# %%
import pandas as pd
from collections import Counter
import re

# Reload news data
df_news = pd.read_csv("../data/raw/raw_analyst_ratings.csv")

# Clean headlines and extract words
all_words = []
for headline in df_news['headline']:
    words = re.findall(r'\b[a-zA-Z]{4,}\b', str(headline).lower())
    all_words.extend(words)

# Remove common words that are not useful
stop_words = {'that', 'this', 'with', 'from', 'have', 'will', 'been', 'were', 'they', 'their', 'said', 'about', 'would', 'could', 'should', 'after', 'before', 'which', 'when', 'your', 'more', 'also', 'than', 'into', 'over', 'some', 'what', 'time', 'just', 'like', 'than'}

filtered_words = [w for w in all_words if w not in stop_words]

# Count most common words
word_counts = Counter(filtered_words)
top_words = word_counts.most_common(20)

print("Top 20 most common words in headlines:")
for word, count in top_words:
    print(f"{word}: {count:,}")
# Out:
# Top 20 most common words in headlines:
# stocks: 161,776
# market: 120,558
# shares: 114,313
# reports: 108,710
# update: 91,723
# earnings: 87,399
# sales: 79,645
# benzinga: 74,516
# week: 69,572
# announces: 66,591
# price: 64,407
# downgrades: 61,959
# trading: 61,182
# raises: 57,802
# upgrades: 56,811
# target: 54,714
# maintains: 52,961
# down: 50,060
# higher: 48,286
# session: 45,349

# %%
import matplotlib.pyplot as plt

words = [w[0] for w in top_words]
counts = [w[1] for w in top_words]

plt.figure(figsize=(12, 6))
plt.barh(words[::-1], counts[::-1], color='steelblue')
plt.title('Top 20 Most Common Words in Financial News Headlines')
plt.xlabel('Number of Occurrences')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# Reload news data
df_news = pd.read_csv("../data/raw/raw_analyst_ratings.csv")

# Take a sample for speed
sample = df_news['headline'].dropna().sample(10000, random_state=42)

# Apply TF-IDF
tfidf = TfidfVectorizer(max_features=20, stop_words='english')
tfidf_matrix = tfidf.fit_transform(sample)

# Get top terms
terms = tfidf.get_feature_names_out()
scores = tfidf_matrix.sum(axis=0).A1
tfidf_scores = dict(zip(terms, scores))
sorted_terms = sorted(tfidf_scores.items(), key=lambda x: x[1], reverse=True)

print("Top 20 terms by TF-IDF score:")
for term, score in sorted_terms:
    print(f"{term}: {score:.2f}")
# Out:
# Top 20 terms by TF-IDF score:
# stocks: 833.55
# market: 616.66
# shares: 557.73
# earnings: 527.83
# vs: 485.23
# update: 470.91
# eps: 448.36
# reports: 444.79
# benzinga: 430.74
# announces: 411.62
# pt: 407.86
# est: 400.70
# price: 385.51
# mid: 339.25
# sales: 334.63
# buy: 328.18
# upgrades: 324.94
# week: 324.84
# trading: 317.73
# 52: 269.93

# %%
import matplotlib.pyplot as plt

terms_list = [t[0] for t in sorted_terms]
scores_list = [t[1] for t in sorted_terms]

plt.figure(figsize=(12, 6))
plt.barh(terms_list[::-1], scores_list[::-1], color='steelblue')
plt.title('Top 20 Financial Terms by TF-IDF Score')
plt.xlabel('TF-IDF Score')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Reload and prepare
df_news['date'] = pd.to_datetime(df_news['date'], format='mixed', utc=True)
df_news['year_month'] = df_news['date'].dt.to_period('M')

# Count articles per month
monthly_counts = df_news.groupby('year_month').size()
monthly_counts.index = monthly_counts.index.to_timestamp()

# Plot
plt.figure(figsize=(16, 6))
plt.plot(monthly_counts.index, monthly_counts.values, color='steelblue')
plt.fill_between(monthly_counts.index, monthly_counts.values, alpha=0.3)

# Annotate key market events
plt.annotate('2009 Financial\nCrisis Recovery',
    xy=(pd.Timestamp('2009-03-01'), monthly_counts.loc['2009-03-01']),
    xytext=(pd.Timestamp('2009-08-01'), 8000),
    arrowprops=dict(arrowstyle='->', color='red'), fontsize=9, color='red')

plt.annotate('2020 COVID-19\nMarket Crash',
    xy=(pd.Timestamp('2020-03-01'), monthly_counts.loc['2020-03-01']),
    xytext=(pd.Timestamp('2019-06-01'), 180000),
    arrowprops=dict(arrowstyle='->', color='red'), fontsize=9, color='red')

plt.title('Monthly News Volume with Key Market Events Annotated')
plt.xlabel('Date')
plt.ylabel('Number of Articles')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Mube\AppData\Local\Temp\ipykernel_17148\1661343643.py:6: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df_news['year_month'] = df_news['date'].dt.to_period('M')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File pandas/_libs/index.pyx:660, in pandas._libs.index.DatetimeEngine.get_loc()
# --> 660 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:2761, in pandas._libs.hashtable.Int64HashTable.get_item()
# -> 2761 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:2785, in pandas._libs.hashtable.Int64HashTable.get_item()
# -> 2785 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 1235865600000000
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~\news-sentiment-analysis\.venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:628, in pandas._libs.index.DatetimeEngine.get_loc()
# --> 628 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:662, in pandas._libs.index.DatetimeEngine.get_loc()
# --> 662 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: Timestamp('2009-03-01 00:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~\news-sentiment-analysis\.venv\Lib\site-packages\pandas\core\indexes\datetimes.py:996, in DatetimeIndex.get_loc(self, key)
#     995 try:
# --> 996     return Index.get_loc(self, key)
#     997 except KeyError as err:
#
# File ~\news-sentiment-analysis\.venv\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#
# KeyError: Timestamp('2009-03-01 00:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 19
#      15 plt.fill_between(monthly_counts.index, monthly_counts.values, alpha=0.3)
#      16
#      17 # Annotate key market events
#      18 plt.annotate('2009 Financial\nCrisis Recovery',
# ---> 19     xy=(pd.Timestamp('2009-03-01'), monthly_counts.loc['2009-03-01']),
#      20     xytext=(pd.Timestamp('2009-08-01'), 8000),
#      21     arrowprops=dict(arrowstyle='->', color='red'), fontsize=9, color='red')
#      22
#
# File ~\news-sentiment-analysis\.venv\Lib\site-packages\pandas\core\indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
#    1206 maybe_callable = self._raise_callable_usage(key, maybe_callable)
# -> 1207 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\news-sentiment-analysis\.venv\Lib\site-packages\pandas\core\indexing.py:1449, in _LocIndexer._getitem_axis(self, key, axis)
#    1447 # fall thru to straight lookup
#    1448 self._validate_key(key, axis)
# -> 1449 return self._get_label(key, axis=axis)
#
# File ~\news-sentiment-analysis\.venv\Lib\site-packages\pandas\core\indexing.py:1399, in _LocIndexer._get_label(self, label, axis)
#    1397 def _get_label(self, label, axis: AxisInt):
#    1398     # GH#5567 this will fail if the label is not present in the axis.
# -> 1399     return self.obj.xs(label, axis=axis)
#
# File ~\news-sentiment-analysis\.venv\Lib\site-packages\pandas\core\generic.py:4253, in NDFrame.xs(self, key, axis, level, drop_level)
#    4249                     new_index = index[loc : loc + 1]
#    4250                 else:
#    4251                     new_index = index[loc]
#    4252         else:
# -> 4253             loc = index.get_loc(key)
#    4254
#    4255             if isinstance(loc, np.ndarray):
#    4256                 if loc.dtype == np.bool_:
#
# File ~\news-sentiment-analysis\.venv\Lib\site-packages\pandas\core\indexes\datetimes.py:998, in DatetimeIndex.get_loc(self, key)
#     996     return Index.get_loc(self, key)
#     997 except KeyError as err:
# --> 998     raise KeyError(orig_key) from err
#
# KeyError: '2009-03-01'
