# %% [markdown]
# # Financial News Sentiment Analysis - EDA
#
# ## Overview
# In this notebook I explore the financial news dataset to understand
# its structure, content and patterns before doing sentiment analysis.
#
# The dataset contains over 1.4 million news headlines from 2009 to 2020.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import re
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

print("Libraries loaded successfully")
# Out:
# Libraries loaded successfully

# %%
df_news = pd.read_csv("../data/raw/raw_analyst_ratings.csv")
df_news.head()
# Out:
#    Unnamed: 0                                           headline  \
# 0           0            Stocks That Hit 52-Week Highs On Friday
# 1           1         Stocks That Hit 52-Week Highs On Wednesday
# 2           2                      71 Biggest Movers From Friday
# 3           3       46 Stocks Moving In Friday's Mid-Day Session
# 4           4  B of A Securities Maintains Neutral on Agilent...
#
#                                                  url          publisher  \
# 0  https://www.benzinga.com/news/20/06/16190091/s...  Benzinga Insights
# 1  https://www.benzinga.com/news/20/06/16170189/s...  Benzinga Insights
# 2  https://www.benzinga.com/news/20/05/16103463/7...         Lisa Levin
# 3  https://www.benzinga.com/news/20/05/16095921/4...         Lisa Levin
# 4  https://www.benzinga.com/news/20/05/16095304/b...         Vick Meyer
#
#                         date stock
# 0  2020-06-05 10:30:54-04:00     A
# 1  2020-06-03 10:45:20-04:00     A
# 2  2020-05-26 04:30:07-04:00     A
# 3  2020-05-22 12:45:06-04:00     A
# 4  2020-05-22 11:38:59-04:00     A

# %%
print("Shape of data:", df_news.shape)
print("Columns:", df_news.columns.tolist())
# Out:
# Shape of data: (1407328, 6)
# Columns: ['Unnamed: 0', 'headline', 'url', 'publisher', 'date', 'stock']

# %%
print("Missing values in each column:")
print(df_news.isnull().sum())
# Out:
# Missing values in each column:
# Unnamed: 0    0
# headline      0
# url           0
# publisher     0
# date          0
# stock         0
# dtype: int64

# %%
print("Number of unique stocks:", df_news['stock'].nunique())
print("Number of unique publishers:", df_news['publisher'].nunique())
print("\nTop 10 publishers:")
print(df_news['publisher'].value_counts().head(10))
# Out:
# Number of unique stocks: 6204
# Number of unique publishers: 1034
#
# Top 10 publishers:
# publisher
# Paul Quintaro        228373
# Lisa Levin           186979
# Benzinga Newsdesk    150484
# Charles Gross         96732
# Monica Gerson         82380
# Eddie Staley          57254
# Hal Lindon            49047
# ETF Professor         28489
# Juan Lopez            28438
# Benzinga Staff        28114
# Name: count, dtype: int64

# %%
# Add a new column that counts how many words are in each headline
df_news['headline_length'] = df_news['headline'].apply(len)

print("Headline length statistics:")
print(df_news['headline_length'].describe())
# Out:
# Headline length statistics:
# count    1.407328e+06
# mean     7.312051e+01
# std      4.073531e+01
# min      3.000000e+00
# 25%      4.700000e+01
# 50%      6.400000e+01
# 75%      8.700000e+01
# max      5.120000e+02
# Name: headline_length, dtype: float64

# %% [markdown]
# ## Publisher Analysis
# This shows the top 10 publishers by number of articles written.
# Paul Quintaro is the most active with over 228,000 articles.

# %%
plt.figure(figsize=(12, 6))
df_news['publisher'].value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Publishers by Number of Articles')
plt.xlabel('Publisher')
plt.ylabel('Number of Articles')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Headline Length Analysis
# Most headlines are between 47 and 87 characters long.
# The average headline length is 73 characters.

# %%
plt.figure(figsize=(12, 6))
df_news['headline_length'].hist(bins=50, color='steelblue', edgecolor='black')
plt.title('Distribution of Headline Lengths')
plt.xlabel('Headline Length (characters)')
plt.ylabel('Number of Headlines')
plt.tight_layout()
plt.show()

# %%
# Convert date column to proper date format
df_news['date'] = pd.to_datetime(df_news['date'], format='mixed', utc=True)

# Extract just the date (without time)
df_news['date_only'] = df_news['date'].dt.date

print("Date range of news:")
print("Earliest:", df_news['date'].min())
print("Latest:", df_news['date'].max())
# Out:
# Date range of news:
# Earliest: 2009-02-14 00:00:00+00:00
# Latest: 2020-06-11 21:12:35+00:00

# %% [markdown]
# ## News Volume Over Time
# This shows how many articles were published each year.
# We can see which years had the most financial news activity.

# %%
# Count articles per year
df_news['year'] = df_news['date'].dt.year

plt.figure(figsize=(12, 6))
df_news['year'].value_counts().sort_index().plot(kind='bar', color='steelblue')
plt.title('Number of News Articles Per Year')
plt.xlabel('Year')
plt.ylabel('Number of Articles')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
print("=== NEWS DATASET SUMMARY ===")
print(f"Total headlines: {df_news.shape[0]:,}")
print(f"Total columns: {df_news.shape[1]}")
print(f"Unique stocks: {df_news['stock'].nunique():,}")
print(f"Unique publishers: {df_news['publisher'].nunique():,}")
print(f"Date range: {df_news['date'].min()} to {df_news['date'].max()}")
print(f"Average headline length: {df_news['headline_length'].mean():.0f} characters")
# Out:
# === NEWS DATASET SUMMARY ===
# Total headlines: 1,407,328
# Total columns: 9
# Unique stocks: 6,204
# Unique publishers: 1,034
# Date range: 2009-02-14 00:00:00+00:00 to 2020-06-11 21:12:35+00:00
# Average headline length: 73 characters

# %%
import pandas as pd
from collections import Counter
import re

# Reload news data
df_news = pd.read_csv("../data/raw/raw_analyst_ratings.csv")

# Clean headlines and extract words
all_words = []
for headline in df_news['headline']:
    words = re.findall(r'\b[a-zA-Z]{4,}\b', str(headline).lower())
    all_words.extend(words)

# Remove common words that are not useful
stop_words = {'that', 'this', 'with', 'from', 'have', 'will', 'been', 'were', 'they', 'their', 'said', 'about', 'would', 'could', 'should', 'after', 'before', 'which', 'when', 'your', 'more', 'also', 'than', 'into', 'over', 'some', 'what', 'time', 'just', 'like', 'than'}

filtered_words = [w for w in all_words if w not in stop_words]

# Count most common words
word_counts = Counter(filtered_words)
top_words = word_counts.most_common(20)

print("Top 20 most common words in headlines:")
for word, count in top_words:
    print(f"{word}: {count:,}")
# Out:
# Top 20 most common words in headlines:
# stocks: 161,776
# market: 120,558
# shares: 114,313
# reports: 108,710
# update: 91,723
# earnings: 87,399
# sales: 79,645
# benzinga: 74,516
# week: 69,572
# announces: 66,591
# price: 64,407
# downgrades: 61,959
# trading: 61,182
# raises: 57,802
# upgrades: 56,811
# target: 54,714
# maintains: 52,961
# down: 50,060
# higher: 48,286
# session: 45,349

# %%
import matplotlib.pyplot as plt

words = [w[0] for w in top_words]
counts = [w[1] for w in top_words]

plt.figure(figsize=(12, 6))
plt.barh(words[::-1], counts[::-1], color='steelblue')
plt.title('Top 20 Most Common Words in Financial News Headlines')
plt.xlabel('Number of Occurrences')
plt.tight_layout()
plt.show()

# %%
sample = df_news['headline'].dropna().sample(10000, random_state=42)

tfidf = TfidfVectorizer(max_features=20, stop_words='english')
tfidf_matrix = tfidf.fit_transform(sample)

terms = tfidf.get_feature_names_out()
scores = tfidf_matrix.sum(axis=0).A1
tfidf_scores = dict(zip(terms, scores))
sorted_terms = sorted(tfidf_scores.items(), key=lambda x: x[1], reverse=True)

print("Top 20 terms by TF-IDF score:")
for term, score in sorted_terms:
    print(f"{term}: {score:.2f}")
# Out:
# Top 20 terms by TF-IDF score:
# stocks: 833.55
# market: 616.66
# shares: 557.73
# earnings: 527.83
# vs: 485.23
# update: 470.91
# eps: 448.36
# reports: 444.79
# benzinga: 430.74
# announces: 411.62
# pt: 407.86
# est: 400.70
# price: 385.51
# mid: 339.25
# sales: 334.63
# buy: 328.18
# upgrades: 324.94
# week: 324.84
# trading: 317.73
# 52: 269.93

# %%
terms_list = [t[0] for t in sorted_terms]
scores_list = [t[1] for t in sorted_terms]

plt.figure(figsize=(12, 6))
plt.barh(terms_list[::-1], scores_list[::-1], color='steelblue')
plt.title('Top 20 Financial Terms by TF-IDF Score')
plt.xlabel('TF-IDF Score')
plt.tight_layout()
plt.show()

# %%
sample_headlines = df_news['headline'].dropna().sample(5000, random_state=42)

vectorizer = CountVectorizer(max_features=1000, stop_words='english')
X = vectorizer.fit_transform(sample_headlines)

lda = LatentDirichletAllocation(n_components=5, random_state=42)
lda.fit(X)

feature_names = vectorizer.get_feature_names_out()
print("=== LDA TOPIC MODELING RESULTS ===\n")
for idx, topic in enumerate(lda.components_):
    top_words = [feature_names[i] for i in topic.argsort()[-10:]]
    print(f"Topic {idx + 1}: {', '.join(top_words)}")
# Out:
# === LDA TOPIC MODELING RESULTS ===
#
# Topic 1: mid, 00, market, maintains, raises, target, price, buy, pt, update
# Topic 2: biotech, february, january, ceo, share, outlook, announces, scheduled, says, earnings
# Topic 3: friday, pre, day, moving, session, market, 52, benzinga, week, stocks
# Topic 4: stocks, industry, oil, market, companies, lower, higher, stock, trading, shares
# Topic 5: sees, q1, q2, q4, q3, sales, reports, eps, est, vs

# %%
print("=== NEWS DATASET SUMMARY ===")
print(f"Total headlines: {df_news.shape[0]:,}")
print(f"Unique stocks: {df_news['stock'].nunique():,}")
print(f"Unique publishers: {df_news['publisher'].nunique():,}")
print(f"Date range: {df_news['date'].min()} to {df_news['date'].max()}")
print(f"Average headline length: {df_news['headline'].apply(len).mean():.0f} characters")
# Out:
# === NEWS DATASET SUMMARY ===
# Total headlines: 1,407,328
# Unique stocks: 6,204
# Unique publishers: 1,034
# Date range: 2009-02-14 00:00:00 to 2020-06-11 17:12:35-04:00
# Average headline length: 73 characters

# %%
# Extract domains from email-format publisher names
def extract_domain(publisher):
    if '@' in str(publisher):
        return str(publisher).split('@')[1]
    return None

df_news['domain'] = df_news['publisher'].apply(extract_domain)
email_publishers = df_news[df_news['domain'].notna()]

print(f"Publishers using email format: {email_publishers['publisher'].nunique()}")
print("\nTop 10 domains:")
print(email_publishers['domain'].value_counts().head(10))
# Out:
# Publishers using email format: 18
#
# Top 10 domains:
# domain
# benzinga.com              7937
# gmail.com                  139
# andyswan.com                 5
# investdiva.com               2
# tothetick.com                2
# eosdetroit.io                1
# forextraininggroup.com       1
# stockmetrix.net              1
# Name: count, dtype: int64

# %%
if len(email_publishers) > 0:
    plt.figure(figsize=(12, 5))
    email_publishers['domain'].value_counts().head(10).plot(kind='bar', color='steelblue')
    plt.title('Top 10 Publisher Domains (Email-format Publishers)')
    plt.xlabel('Domain')
    plt.ylabel('Number of Articles')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
else:
    print("No email-format publishers found in dataset")
